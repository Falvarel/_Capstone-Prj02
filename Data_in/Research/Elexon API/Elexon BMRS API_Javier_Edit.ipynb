# %% [markdown]
# # **Elexon BMRS API**
#
# A simple wrapper for the Elexon BMRS API.
#
# https://pypi.org/project/elexon/
#
# https://github.com/michaelkavanagh/elexon

# %% [markdown]
# https://bscdocs.elexon.co.uk/guidance-notes/bmrs-api-and-data-push-user-guide

# %% [markdown]
# ## **Installing**
#
# Install with pip (recommended):
#
#     $ pip install elexon
#
# Alternatively, you can grab the latest source code from GitHub:
#
#     $ git clone https://github.com/MichaelKavanagh/elexon.git
#     $ python setup.py install

# %% [markdown]
# ## **Getting Started**
#
# 1. Register on the ELEXON Portal.
# 2. Retrieve API Key.
# 3. Replace API_KEY in the example below with your API Key.
# 4. Profit.

# %% [markdown]
# ## **Usage**
# - Supported Elexon BMRS Reports
# - For the full list of namespaces, methods, parameters and data types see methods.py.

# %% [markdown]
# ## **Methods**

# %% [markdown]
#     METHODS = {
#     # Transparency Data
#     'Transparency': {
#         'B1720': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1730': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1740': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1750': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1760': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1770': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1780': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1790': [
#             ('Year', int, []),
#             ('Month', str, [])
#         ],
#         'B1810': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1820': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1830': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B0610': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B0620': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B0630': [
#             ('Year', int, []),
#             ('Week', int, [])
#         ],
#         'B0640': [
#             ('Year', int, []),
#             ('Month', str, [])  # either format MMM or MM(01-12)?
#         ],
#         'B0650': [
#             ('Year', int, [])
#         ],
#         'B0810': [
#             ('Year', int, [])
#         ],
#         'B1410': [
#             ('Year', int, [])
#         ],
#         'B1420': [
#             ('Year', int, [])
#         ],
#         'B1430': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1440': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1610': [
#             ('SettlementDate', date, []),
#             ('Period', str, []),
#             ('NGCBMUnitID', str, ['optional'])
#         ],
#         'B1620': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1630': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B0910': [
#             ('Year', int, [])
#         ],
#         'B1320': [
#             ('SettlementDate', date, []),
#             ('Period', str, [])
#         ],
#         'B1330': [
#             ('Year', int, []),
#             ('Month', int, [])
#         ],
#         'B0710': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B0720': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1010': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1020': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1030': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1510': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1520': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1530': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ],
#         'B1540': [
#             ('StartDate', date, []),
#             ('StartTime', time, []),
#             ('EndDate', date, []),
#             ('EndTime', time, [])
#         ]
#     },
#
#     # REMIT
#     'REMIT': {
#         'MessageListRetrieval': [
#             ('EventStart', date, ['optional']),
#             ('EventEnd', date, ['optional']),
#             ('PublicationFrom', date, ['optional']),
#             ('PublicationTo', date, ['optional']),
#             ('ParticipantId', str, ['optional']),
#             ('MessageID', str, ['optional']),
#             ('AssetID', str, ['optional']),
#             ('EventType', str, ['optional']),
#             ('FuelType', str, ['optional']),
#             ('MessageType', str, ['optional']),
#             ('UnavailabilityType', str, ['optional']),
#             ('AffectedUnitID', str, ['optional']),
#             ('ActiveFlag', str, ['optional'])
#         ],
#         'MessageDetailRetrieval': [
#             ('MessageId', str, []),
#             ('ParticipantId', str, []),
#             ('SequenceId', str, ['optional']),
#             ('ActiveFlag', str, ['optional'])
#         ]
#     },
#
#     # Legacy BMRS Data
#     'Legacy': {
#         'TEMP': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'BOD': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('LeadPartyName', str, ['optional']),
#             ('NGCBMUnitName', str, ['optional'])
#         ],
#         'CDN': [
#             ('FromClearedDate', date, ['optional']),
#             ('ToClearedDate', date, ['optional'])
#         ],
#         'SYSWARN': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'DISBSAD': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional'])
#         ],
#         'NETBSAD': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional']),
#             ('IsTwoDayWindow', bool, ['optional'])
#         ],
#         'FREQ': [
#             ('FromDateTime', datetime, ['optional']),
#             ('ToDateTime', datetime, ['optional'])
#         ],
#         'MID': [
#             ('FromSettlementDate', date, ['optional']),
#             ('ToSettlementDate', date, ['optional']),
#             ('Period', str, ['optional'])
#         ],
#         'DEVINDOD': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'NONBM': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'QAS': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional']),
#             ('BmUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('LeadPartyName', str, ['optional']),
#             ('NgcBmUnitName', str, ['optional'])
#         ],
#         'ROLSYSDEM': [
#             ('FromDateTime', datetime, ['optional']),
#             ('ToDateTime', datetime, ['optional'])
#         ],
#         'WINDFORPK': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'WINDFORFUELHH': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'FUELINSTHHCUR': [
#             ('FuelType', str, ['optional'])
#         ],
#         'FUELINST': [
#             ('FromDateTime', datetime, ['optional']),
#             ('ToDateTime', datetime, ['optional'])
#         ],
#         'FUELHH': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'INTERFUELHH': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'NOU2T14D': [],
#         'FOU2T14D': [],
#         'UOU2T14D': [],
#         'NOU2T52W': [],
#         'FOU2T52W': [],
#         'UOU2T52W': [],
#         'NOUY1': [],
#         'NOUY2': [],
#         'NOUY3': [],
#         'NOUY4': [],
#         'NOUY5': [],
#         'ZOU2T14D': [],
#         'ZOU2T52W': [],
#         'ZOUY1': [],
#         'ZOUY2': [],
#         'ZOUY3': [],
#         'ZOUY4': [],
#         'ZOUY5': [],
#         'INDOITSDO': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'MELIMBALNGC': [
#             ('ZoneIdentifier', str, ['optional']),
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'FORDAYDEM': [
#             ('ZoneIdentifier', str, ['optional']),
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'DEMMF2T14D': [],
#         'DEMMF2T52W': [],
#         'SOSOP': [
#             ('SettlementDate', date, ['optional']),
#             ('StartTime', time, ['optional']),
#             ('TradeType', str, ['optional']),
#             ('IsTwoDayWindow', bool, ['optional'])
#         ],
#         'SOSOT': [],
#         'PKDEMYESTTDYTOM': [],
#         'INDPKDEMINFO': [],
#         'SYSDEM': [
#             ('FromDate', date, ['optional']),
#             ('ToDate', date, ['optional'])
#         ],
#         'INDTRIADDEMINFO': [],
#         'PHYBMDATA': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('LeadPartyName', str, ['optional']),
#             ('NGCBMUnitName', str, ['optional'])
#         ],
#         'DYNBMDATA': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('LeadPartyName', str, ['optional']),
#             ('NGCBMUnitName', str, ['optional'])
#         ],
#         'DERBMDATA': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('LeadPartyName', str, ['optional']),
#             ('NGCBMUnitName', str, ['optional'])
#         ],
#         'DERSYSDATA': [
#             ('FromSettlementDate', date, ['optional']),
#             ('ToSettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional'])
#         ],
#         'DETSYSPRICES': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional'])
#         ],
#         'MKTDEPTHDATA': [
#             ('SettlementDate', date, ['optional'])
#         ],
#         'LATESTACCEPTS': [],
#         'HISTACCEPTS': [
#             ('SettlementDate', date, ['optional']),
#             ('SettlementPeriod', str, ['optional'])
#         ],
#         'SYSMSG': [],
#         'BMUNITSEARCH': [
#             ('BMUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('LeadPartyName', str, ['optional']),
#             ('NGCBMUnitName', str, ['optional'])
#         ],
#         'SYSWARNTDYTOM': [],
#         'HISTSYSWARN': [],
#         'LOLPDRM': [
#             ('FromSettlementDate', date, ['optional']),
#             ('ToSettlementDate', date, ['optional'])
#         ],
#         'DEMCI': [
#             ('FromSettlementDate', date, ['optional']),
#             ('ToSettlementDate', date, ['optional'])
#         ],
#         'STORAW': [
#             ('FromSettlementDate', date, ['optional'])
#         ],
#         'TRADINGUNIT': [
#             ('SettlementDate', date, []),
#             ('SettlementPeriod', str, []),
#             ('TradeType', str, ['optional']),
#             ('TradeName', str, ['optional'])
#         ],
#         'EURGBFXDATA': [
#             ('SettlementDayFrom', date, []),
#             ('SettlementDayTo', date, ['optional'])
#         ]
#     },
#
#     # Replacement Reserve Data
#     'ReplacementReserveData': {
#         'RRBidData': [
#             ('SettlementDate', date, []),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional']),
#             ('BMUnitType', str, ['optional']),
#             ('NGCBMUnitName', str, ['optional']),
#             ('ParticipantId', str, ['optional'])
#         ],
#         'RRAggregatedInfo': [
#             ('DateTimeFrom', datetime, []),
#             ('DateTimeTo', datetime, ['optional'])
#         ],
#         'RRActivation': [
#             ('SettlementDate', date, []),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional'])
#         ],
#         'RRINTCON': [
#             ('SettlementDate', date, []),
#             ('SettlementPeriod', str, ['optional']),
#             ('InterconnectorId', str, ['optional'])
#         ],
#         'RRGBNM': [
#             ('SettlementDate', date, []),
#             ('SettlementPeriod', str, ['optional'])
#         ],
#         'RRCashflow': [
#             ('SettlementDate', date, []),
#             ('SettlementPeriod', str, ['optional']),
#             ('BMUnitId', str, ['optional'])
#         ]
#     }
#     }

# %% [markdown]
# ## **Tests**

# %%
pip install elexon
# Out:
# Collecting elexon
#   Downloading elexon-0.2.3-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from elexon) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (3.4)
# Installing collected packages: elexon
# Successfully installed elexon-0.2.3

# %%
from elexon import ElexonRawClient
import pandas as pd

# %%
api = ElexonRawClient('qpbbkt7aaj03f8p') # 'API_KEY' -> available for free from the Elexon Portal

# %%
# Actual Aggregated Generation per Type
generation_01 = api.Transparency.B1620(SettlementDate = '2020-01-01', Period = '5')

# %%
pd.DataFrame(generation_01)

# %%
# Alternatively, use the general request() function by passing the endpoint in with the arguments:
generation_02 = api.request('B1620', SettlementDate = '2020-01-01', Period = '5')

# %%
pd.DataFrame(generation_02)

# %% [markdown]
# ## **Data requests**

# %%
pip install elexon
# Out:
# Requirement already satisfied: elexon in /usr/local/lib/python3.10/dist-packages (0.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from elexon) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->elexon) (3.4)

# %%
from elexon import ElexonRawClient
import pandas as pd

# %%
api = ElexonRawClient('qpbbkt7aaj03f8p') # 'API_KEY' -> available for free from the Elexon Portal

# %% [markdown]
# ##### 5.1.3	B1740 – Accepted Aggregated Offers

# %%
'''
'B1740': [ ('SettlementDate', date, []),
           ('Period', str, []) ]
'''

# %%
#generation = api.request('B1740', SettlementDate='2014-12-01', Period='1')

# %%
#pd.DataFrame(generation)

# %% [markdown]
# ##### 5.1.13	B0620 – Day-Ahead Total Load Forecast per Bidding Zone

# %%
'''
'B0620': [ ('SettlementDate', date, []),
           ('Period', str, []) ]
'''

# %%
generation = api.request('B0620', SettlementDate='2020-01-01', Period='20')

# %%
pd.DataFrame(generation)
# Out:
#                   timeSeriesID settlementDate  settlementPeriod  quantity  \
# 0  NGET-EMFIP-DATL-TS-00036862     2020-01-01                20     29759
#
#         documentType businessType processType objectAggregation  \
# 0  System total load  Consumption   Day Ahead              Area
#
#                      curveType resolution unitOfMeasure  activeFlag  \
# 0  Sequential fixed size block      PT30M     Mega watt        True
#
#                  documentID  documentRevNum
# 0  NGET-EMFIP-DATL-00036442               1

# %% [markdown]
# ##### 5.1.20	B1430 – Day-Ahead Aggregated Generation

# %%
'''
'B1430': [ ('SettlementDate', date, []),
           ('Period', str, []) ]
'''

# %%
generation = api.request('B1430', SettlementDate='2020-01-01', Period='20')

# %%
pd.DataFrame(generation)
# Out:
#           documentType businessType processType                timeSeriesID  \
# 0  Generation forecast   Production   Day Ahead  NGET-EMFIP-DAG-TS-00036023
#
#    quantity                    curveType resolution settlementDate  \
# 0     26281  Sequential fixed size block      PT30M     2020-01-01
#
#    settlementPeriod  activeFlag               documentID  documentRevNum
# 0                20        True  NGET-EMFIP-DAG-00035703               1

# %% [markdown]
# ##### 5.1.21	B1440 –Generation forecasts for Wind and Solar

# %%
'''
'B1440': [ ('SettlementDate', date, []),
           ('Period', str, []) ]
'''

# %%
generation = api.request('B1440', SettlementDate='2023-07-03', Period='20')

# %%
df_x = pd.DataFrame(generation)
df_x
# Out:
#                           timeSeriesID      businessType  \
# 0          NGET-EMFIP-DGWS-TS-06239467  Solar generation
# 1          NGET-EMFIP-DGWS-TS-06239465   Wind generation
# 2          NGET-EMFIP-DGWS-TS-06239466   Wind generation
# 3  NGET-EMFIP-DGWSINTRADAY-TS-06238956  Solar generation
# 4  NGET-EMFIP-DGWSINTRADAY-TS-06238954   Wind generation
# 5  NGET-EMFIP-DGWSINTRADAY-TS-06238955   Wind generation
#
#   powerSystemResourceType settlementDate processType  settlementPeriod  \
# 0                 "Solar"     2023-07-03   Day Ahead                20
# 1         "Wind Offshore"     2023-07-03   Day Ahead                20
# 2          "Wind Onshore"     2023-07-03   Day Ahead                20
# 3                 "Solar"     2023-07-03    Intraday                20
# 4         "Wind Offshore"     2023-07-03    Intraday                20
# 5          "Wind Onshore"     2023-07-03    Intraday                20
#
#    quantity             documentType                    curveType resolution  \
# 0  4699.000  Wind and solar forecast  Sequential fixed size block      PT30M
# 1  8834.981  Wind and solar forecast  Sequential fixed size block      PT30M
# 2  6598.212  Wind and solar forecast  Sequential fixed size block      PT30M
# 3  3420.000  Wind and solar forecast  Sequential fixed size block      PT30M
# 4  8574.424  Wind and solar forecast  Sequential fixed size block      PT30M
# 5  6744.241  Wind and solar forecast  Sequential fixed size block      PT30M
#
#    activeFlag                        documentID  documentRevNum
# 0        True          NGET-EMFIP-DGWS-06244402               1
# 1        True          NGET-EMFIP-DGWS-06244402               1
# 2        True          NGET-EMFIP-DGWS-06244402               1
# 3        True  NGET-EMFIP-DGWSINTRADAY-06043320               1
# 4        True  NGET-EMFIP-DGWSINTRADAY-06043320               1
# 5        True  NGET-EMFIP-DGWSINTRADAY-06043320               1

# %%
df = pd.DataFrame()
df['Solar generation'] = df_x[(df_x['businessType']=='Solar generation')&(df_x['settlementPeriod']==20)]['quantity']
df['Wind generation Offshore'] = df_x[(df_x['businessType']=='Wind generation')&(df_x['settlementPeriod']==20)]['quantity']
df['Wind generation Onshore'] = df_x[(df_x['businessType']=='Wind generation')&(df_x['settlementPeriod']==20)]['quantity']
df['settlementPeriod'] =

# %%
df
# Out:
#    Solar generation
# 0            4699.0
# 3            3420.0

# %%
generation = api.request('B1440', SettlementDate='2023-07-03', Period='1')

# %%
pd.DataFrame(generation)

# %%
from datetime import date, timedelta

start_date = date(2021, 1, 1)
end_date = date(2023, 6, 30)    # perhaps date.now()

delta = end_date - start_date   # returns timedelta

# %%
df_final = pd.DataFrame()

for x in range(delta.days + 1):

  day = start_date + timedelta(days=x)

  for y in range(1,49):
    generation = api.request('B1440', SettlementDate=str(day), Period=str(y))
    df = pd.DataFrame(generation)
    df_final = pd.concat([df_final,df])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-c97cb212e4b2> in <cell line: 3>()
#       6
#       7   for y in range(1,49):
# ----> 8     generation = api.request('B1440', SettlementDate=str(day), Period=str(y))
#       9     df = pd.DataFrame(generation)
#      10     df_final = pd.concat([df_final,df])
#
# /usr/local/lib/python3.10/dist-packages/elexon/elexon.py in request(self, report_name, **kwargs)
#     129     def request(self, report_name: str, **kwargs):
#     130         """General request function, takes the report endpoint (method) as first positional arg"""
# --> 131         response = self.base_request(report_name, kwargs)
#     132         return self._parse_response(response, report_name)
#     133
#
# /usr/local/lib/python3.10/dist-packages/elexon/elexon.py in base_request(self, report_name, args)
#     146         except requests.exceptions.HTTPError as e:
#     147             logging.debug(f'URL: {response.url}')
# --> 148             raise e
#     149         else:
#     150             return response
#
# /usr/local/lib/python3.10/dist-packages/elexon/elexon.py in base_request(self, report_name, args)
#     143         try:
#     144             response = self.session.get(url=url, params=args, proxies=self.proxies)
# --> 145             response.raise_for_status()
#     146         except requests.exceptions.HTTPError as e:
#     147             logging.debug(f'URL: {response.url}')
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#     958
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#     962     def close(self):
#
# HTTPError: 502 Server Error: Bad Gateway for url: https://api.bmreports.com/BMRS/B1440/v1?SettlementDate=2021-01-10&Period=36&APIKey=qpbbkt7aaj03f8p&ServiceType=xml

# %%
df_final
# Out:
#                            timeSeriesID      businessType  \
# 0           NGET-EMFIP-DGWS-TS-06236110  Solar generation
# 1           NGET-EMFIP-DGWS-TS-06236108   Wind generation
# 2           NGET-EMFIP-DGWS-TS-06236109   Wind generation
# 0           NGET-EMFIP-DGWS-TS-06236110  Solar generation
# 1           NGET-EMFIP-DGWS-TS-06236108   Wind generation
# ..                                  ...               ...
# 4   NGET-EMFIP-DGWSINTRADAY-TS-06235540   Wind generation
# 5   NGET-EMFIP-DGWSINTRADAY-TS-06235541   Wind generation
# 6    NGET-EMFIP-DGWSCURRENT-TS-06234983  Solar generation
# 7    NGET-EMFIP-DGWSCURRENT-TS-06234981   Wind generation
# 8    NGET-EMFIP-DGWSCURRENT-TS-06234982   Wind generation
#
#    powerSystemResourceType settlementDate processType  settlementPeriod  \
# 0                  "Solar"     2021-01-01   Day Ahead                 1
# 1          "Wind Offshore"     2021-01-01   Day Ahead                 1
# 2           "Wind Onshore"     2021-01-01   Day Ahead                 1
# 0                  "Solar"     2021-01-01   Day Ahead                 2
# 1          "Wind Offshore"     2021-01-01   Day Ahead                 2
# ..                     ...            ...         ...               ...
# 4          "Wind Offshore"     2021-01-10    Intraday                35
# 5           "Wind Onshore"     2021-01-10    Intraday                35
# 6                  "Solar"     2021-01-10     Current                35
# 7          "Wind Offshore"     2021-01-10     Current                35
# 8           "Wind Onshore"     2021-01-10     Current                35
#
#     quantity             documentType                    curveType resolution  \
# 0      0.000  Wind and solar forecast  Sequential fixed size block      PT30M
# 1   2082.297  Wind and solar forecast  Sequential fixed size block      PT30M
# 2   3300.832  Wind and solar forecast  Sequential fixed size block      PT30M
# 0      0.000  Wind and solar forecast  Sequential fixed size block      PT30M
# 1   2082.297  Wind and solar forecast  Sequential fixed size block      PT30M
# ..       ...                      ...                          ...        ...
# 4   3479.623  Wind and solar forecast  Sequential fixed size block      PT30M
# 5   4980.727  Wind and solar forecast  Sequential fixed size block      PT30M
# 6      0.000  Wind and solar forecast  Sequential fixed size block      PT30M
# 7   3565.223  Wind and solar forecast  Sequential fixed size block      PT30M
# 8   4992.254  Wind and solar forecast  Sequential fixed size block      PT30M
#
#     activeFlag                        documentID  documentRevNum
# 0         True          NGET-EMFIP-DGWS-06239638               1
# 1         True          NGET-EMFIP-DGWS-06239638               1
# 2         True          NGET-EMFIP-DGWS-06239638               1
# 0         True          NGET-EMFIP-DGWS-06239638               1
# 1         True          NGET-EMFIP-DGWS-06239638               1
# ..         ...                               ...             ...
# 4         True  NGET-EMFIP-DGWSINTRADAY-06038284               1
# 5         True  NGET-EMFIP-DGWSINTRADAY-06038284               1
# 6         True   NGET-EMFIP-DGWSCURRENT-06038045               1
# 7         True   NGET-EMFIP-DGWSCURRENT-06038045               1
# 8         True   NGET-EMFIP-DGWSCURRENT-06038045               1
#
# [3123 rows x 13 columns]

# %% [markdown]
# ##### 5.2.1	Temperature Data

# %%
'''
'TEMP': [ ('FromDate', date, ['optional']),
          ('ToDate', date, ['optional']) ]
'''

# %%
generation = api.request('TEMP', FromDate='2023-07-01', ToDate='2023-08-04')

# %%
pd.DataFrame(generation)
# Out:
#   recordType publishingPeriodCommencingTime  temperature  \
# 0       TEMP                     2023-07-01         17.1
# 1       TEMP                     2023-07-02         16.7
#
#    normalReferenceTemperature  lowReferenceTemperature  \
# 0                        16.9                     15.1
# 1                        16.9                     15.1
#
#    highReferenceTemperature  activeFlag
# 0                      19.9        True
# 1                      20.0        True

# %% [markdown]
# ##### 5.2.2	Bid Offer Level Data

# %%
'''
'BOD': [ ('SettlementDate', date, ['optional']),
         ('SettlementPeriod', str, ['optional']),
         ('BMUnitId', str, ['optional']),
         ('BMUnitType', str, ['optional']),
         ('LeadPartyName', str, ['optional']),
         ('NGCBMUnitName', str, ['optional']) ]
'''

# %%
generation = api.request('BOD')#, SettlementPeriod='20')

# %%
pd.DataFrame(generation)
# Out:
#      recordType     bmUnitID bMUnitType            leadPartyName  \
# 0           BOD  2__AANGE002          S  Limejump Energy Limited
# 1           BOD  2__AANGE002          S  Limejump Energy Limited
# 2           BOD  2__ABGAS000          G  British Gas Trading Ltd
# 3           BOD  2__ABGAS000          G  British Gas Trading Ltd
# 4           BOD  2__ABIZZ000          G  British Gas Trading Ltd
# ...         ...          ...        ...                      ...
# 2726        BOD  V__NFLEX001          V     Flexitricity Limited
# 2727        BOD  V__NFLEX002          V     Flexitricity Limited
# 2728        BOD  V__NFLEX002          V     Flexitricity Limited
# 2729        BOD  V__PFLEX001          V     Flexitricity Limited
# 2730        BOD  V__PFLEX001          V     Flexitricity Limited
#
#      ngcBMUnitName settlementDate  settlementPeriod  bidOfferPairNumber  \
# 0        AG-ALIM03     2023-07-03                 7                   1
# 1        AG-ALIM03     2023-07-03                 7                  -1
# 2        EAS-BGS01     2023-07-03                 7                   1
# 3        EAS-BGS01     2023-07-03                 7                  -1
# 4        EAS-BIZ01     2023-07-03                 7                   1
# ...            ...            ...               ...                 ...
# 2726     AG-FLX02N     2023-07-03                 7                  -1
# 2727     AG-FLX07N     2023-07-03                 7                   1
# 2728     AG-FLX07N     2023-07-03                 7                  -1
# 2729     AG-FLX01P     2023-07-03                 7                   1
# 2730     AG-FLX01P     2023-07-03                 7                  -1
#
#                 timeFrom  bidOfferLevelFrom              timeTo  \
# 0    2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 1    2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 2    2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 3    2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 4    2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# ...                  ...                ...                 ...
# 2726 2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 2727 2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 2728 2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 2729 2023-07-03 02:00:00                  0 2023-07-03 02:30:00
# 2730 2023-07-03 02:00:00                 -1 2023-07-03 02:30:00
#
#       bidOfferLevelTo  bidPrice  offerPrice  activeFlag
# 0                   0       0.0         0.0        True
# 1                   0       0.0         0.0        True
# 2                   0       0.0         0.0        True
# 3                   0       0.0         0.0        True
# 4                   0       0.0         0.0        True
# ...               ...       ...         ...         ...
# 2726                0   -9999.0     -9000.0        True
# 2727                0       0.0         0.0        True
# 2728                0       0.0         0.0        True
# 2729                0    9000.0      9999.0        True
# 2730               -1     -15.0        10.0        True
#
# [2731 rows x 15 columns]

# %% [markdown]
# ##### 5.2.14	Wind Generation Forecast and Out-turn Data

# %%
'''
'WINDFORFUELHH': [('FromDate', date, ['optional']),
                  ('ToDate', date, ['optional'])
                  ]
'''

# %%
generation = api.request('WINDFORFUELHH', FromDate='2023-07-04', ToDate='2023-07-04')

# %%
pd.DataFrame(generation)
# Out:
#    recordType startTimeOfHalfHrPeriod  settlementPeriod  \
# 0        WIND              2023-07-04                 1
# 1        WIND              2023-07-04                 3
# 2        WIND              2023-07-04                 5
# 3        WIND              2023-07-04                 7
# 4        WIND              2023-07-04                 9
# 5        WIND              2023-07-04                11
# 6        WIND              2023-07-04                13
# 7        WIND              2023-07-04                15
# 8        WIND              2023-07-04                17
# 9        WIND              2023-07-04                19
# 10       WIND              2023-07-04                21
# 11       WIND              2023-07-04                23
# 12       WIND              2023-07-04                25
# 11               None        True
# 12               None        True
# 13               None        True
# 14               None        True
# 15               None        True
# 16               None        True
# 17               None        True
# 18               None        True
# 19               None        True
# 20               None        True
# 21               None        True

# %% [markdown]
# ##### 5.2.29	Forecast Day and Day Ahead Margin and Imbalance Data

# %%
'''
'MELIMBALNGC': [ ('ZoneIdentifier', str, ['optional']),
                 ('FromDate', date, ['optional']),
                 ('ToDate', date, ['optional']) ]
'''

# %%
generation = api.request('MELIMBALNGC', FromDate='2021-01-01', ToDate='2021-01-01')

# %%
pd.DataFrame(generation)
# Out:
#    recordType settlementDate  settlementPeriod nationalBoundaryIdentifier  \
# 0         DAM     2021-01-01                 1                          N
# 1         DAM     2021-01-01                 2                          N
# 2         DAM     2021-01-01                 3                          N
# 3         DAM     2021-01-01                 4                          N
# 4         DAM     2021-01-01                 5                          N
# ..        ...            ...               ...                        ...
# 91        DAI     2021-01-01                44                          N
# 92        DAI     2021-01-01                45                          N
# 93        DAI     2021-01-01                46                          N
# 94        DAI     2021-01-01                47                          N
# 95        DAI     2021-01-01                48                          N
#
#    publishingPeriodCommencingTime   margin  activeFlag  imbalanceValue
# 0             2020-12-31 23:45:00  29229.0        True             NaN
# 1             2021-01-01 00:15:00  29314.0        True             NaN
# 2             2021-01-01 00:45:00  29385.0        True             NaN
# 3             2021-01-01 01:15:00  30038.0        True             NaN
# 4             2021-01-01 01:45:00  30396.0        True             NaN
# ..                            ...      ...         ...             ...
# 91            2021-01-01 21:15:00      NaN        True           -62.0
# 92            2021-01-01 21:45:00      NaN        True           150.0
# 93            2021-01-01 22:15:00      NaN        True          -317.0
# 94            2021-01-01 22:45:00      NaN        True           163.0
# 95            2021-01-01 23:15:00      NaN        True           -85.0
#
# [96 rows x 8 columns]

# %% [markdown]
# ##### 5.2.30	Forecast Day and Day Ahead Demand Data

# %%
'''
'FORDAYDEM': [ ('ZoneIdentifier', str, ['optional']),
               ('FromDate', date, ['optional']),
               ('ToDate', date, ['optional']) ]
'''

# %%
generation = api.request('FORDAYDEM', FromDate='2021-01-01', ToDate='2021-01-01')

# %%
pd.DataFrame(generation)
# Out:
#     nationalBoundaryIdentifier settlementDate  settlementPeriod recordType  \
# 0                            N     2021-01-01                 1       DANF
# 1                            N     2021-01-01                 2       DANF
# 2                            N     2021-01-01                 3       DANF
# 3                            N     2021-01-01                 4       DANF
# 4                            N     2021-01-01                 5       DANF
# ..                         ...            ...               ...        ...
# 187                          N     2021-01-01                44       DATF
# 188                          N     2021-01-01                45       DATF
# 189                          N     2021-01-01                46       DATF
# 190                          N     2021-01-01                47       DATF
# 191                          N     2021-01-01                48       DATF
#
#     publishingPeriodCommencingTime   demand  activeFlag  spnDemand  \
# 0              2020-12-31 23:45:00  28930.0        True        NaN
# 1              2021-01-01 00:15:00  28960.0        True        NaN
# 2              2021-01-01 00:45:00  28527.0        True        NaN
# 3              2021-01-01 01:15:00  27599.0        True        NaN
# 4              2021-01-01 01:45:00  26820.0        True        NaN
# ..                             ...      ...         ...        ...
# 187            2021-01-01 21:15:00  32059.0        True        NaN
# 188            2021-01-01 21:45:00  30782.0        True        NaN
# 189            2021-01-01 22:15:00  29772.0        True        NaN
# 190            2021-01-01 22:45:00  28473.0        True        NaN
# 191            2021-01-01 23:15:00  27560.0        True        NaN
#
#      spnGeneration
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 187            NaN
# 188            NaN
# 189            NaN
# 190            NaN
# 191            NaN
#
# [192 rows x 9 columns]

# %% [markdown]
# ##### 5.2.40	Physical Data

# %%
'''
'PHYBMDATA': [ ('SettlementDate', date, ['optional']),
               ('SettlementPeriod', str, ['optional']),
               ('BMUnitId', str, ['optional']),
               ('BMUnitType', str, ['optional']),
               ('LeadPartyName', str, ['optional']),
               ('NGCBMUnitName', str, ['optional']) ]
'''

# %%
generation = api.request('PHYBMDATA')

# %%
df = pd.DataFrame(generation)
df
# Out:
#      recordType     bmUnitID bMUnitType                leadPartyName  \
# 0            PN  2__AANGE002          S      Limejump Energy Limited
# 1            PN  2__ABGAS000          G      British Gas Trading Ltd
# 2            PN  2__ABIZZ000          G      British Gas Trading Ltd
# 3            PN  2__ACNDL001          S             NEAS Energy Ltd.
# 4            PN  2__AECOT003          S  The Renewable Energy Co Ltd
# ...         ...          ...        ...                          ...
# 6624      BOALF    T_STRNW-1          T    Strathy Wind Farm Limited
# 6625      BOALF    T_WDRGW-1          T  Windy Rig Wind Farm Limited
# 6626      BOALF    T_WDRGW-1          T  Windy Rig Wind Farm Limited
# 6627      BOALF    T_WISTW-2          T   BROCKLOCH RIG WINDFARM LTD
# 6628      BOALF    T_WISTW-2          T   BROCKLOCH RIG WINDFARM LTD
#
#      ngcBMUnitName settlementDate  settlementPeriod            timeFrom  \
# 0        AG-ALIM03     2023-07-03                 9 2023-07-03 03:00:00
# 1        EAS-BGS01     2023-07-03                 9 2023-07-03 03:00:00
# 2        EAS-BIZ01     2023-07-03                 9 2023-07-03 03:00:00
# 3          PETDG-1     2023-07-03                 9 2023-07-03 03:00:00
# 4        AG-AECO01     2023-07-03                 9 2023-07-03 03:00:00
# ...            ...            ...               ...                 ...
# 6624       STRNW-1     2023-07-03                 9 2023-07-03 02:30:00
# 6625       WDRGW-1     2023-07-03                 9 2023-07-03 02:30:00
# 6626       WDRGW-1     2023-07-03                 9 2023-07-03 03:15:00
# 6627       WISTW-2     2023-07-03                 9 2023-07-03 02:26:00
# 6628       WISTW-2     2023-07-03                 9 2023-07-03 03:11:00
#
#       pnLevelFrom              timeTo  ...  milLevelTo  \
# 0             0.0 2023-07-03 03:30:00  ...         NaN
# 1          -190.0 2023-07-03 03:30:00  ...         NaN
# 2             0.0 2023-07-03 03:30:00  ...         NaN
# 3             0.0 2023-07-03 03:30:00  ...         NaN
# 4             0.0 2023-07-03 03:30:00  ...         NaN
# ...           ...                 ...  ...         ...
# 6624          NaN 2023-07-03 03:30:00  ...         NaN
# 6625          NaN 2023-07-03 03:15:00  ...         NaN
# 6626          NaN 2023-07-03 03:20:00  ...         NaN
# 6627          NaN 2023-07-03 03:11:00  ...         NaN
# 6628          NaN 2023-07-03 03:17:00  ...         NaN
#
#       bidOfferAcceptanceNumber      acceptanceTime  deemedBidOfferFlag  \
# 0                          NaN                 NaT                 NaN
# 1                          NaN                 NaT                 NaN
# 2                          NaN                 NaT                 NaN
# 3                          NaN                 NaT                 NaN
# 4                          NaN                 NaT                 NaN
# ...                        ...                 ...                 ...
# 6624                   52837.0 2023-07-03 02:10:00                   F
# 6625                    5469.0 2023-07-03 02:07:00                   F
# 6626                    5469.0 2023-07-03 02:07:00                   F
# 6627                   29716.0 2023-07-03 02:03:00                   F
# 6628                   29716.0 2023-07-03 02:03:00                   F
#
#       soFlag  storProviderFlag  rrInstructionFlag  rrScheduleFlag  \
# 0        NaN               NaN                NaN             NaN
# 1        NaN               NaN                NaN             NaN
# 2        NaN               NaN                NaN             NaN
# 3        NaN               NaN                NaN             NaN
# 4        NaN               NaN                NaN             NaN
# ...      ...               ...                ...             ...
# 6624       T                 F                  F               F
# 6625       T                 F                  F               F
# 6626       T                 F                  F               F
# 6627       T                 F                  F               F
# 6628       T                 F                  F               F
#
#       bidOfferLevelFrom bidOfferLevelTo
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 6624                0.0             0.0
# 6625                0.0             0.0
# 6626                0.0            43.0
# 6627                0.0             0.0
# 6628                0.0            51.0
#
# [6629 rows x 27 columns]

# %%
df[df['recordType']=='BOALF']
# Out:
#      recordType     bmUnitID bMUnitType                  leadPartyName  \
# 6580      BOALF  2__PMARB001          S           Marble Power Limited
# 6581      BOALF  2__PMARB001          S           Marble Power Limited
# 6582      BOALF    E_ASHWW-1          E         Statkraft Markets Gmbh
# 6583      BOALF    E_BRYBW-1          E         Statkraft Markets Gmbh
# 6584      BOALF     E_SHOS-1          E              VPI Power Limited
# 6585      BOALF     E_SHOS-1          E              VPI Power Limited
# 6586      BOALF     E_SHOS-1          E              VPI Power Limited
# 6587      BOALF     E_SHOS-1          E              VPI Power Limited
# 6588      BOALF     T_CARR-2          T           Carrington Power Ltd
# 6589      BOALF     T_CARR-2          T           Carrington Power Ltd
# 6590      BOALF     T_CARR-2          T           Carrington Power Ltd
# 6591      BOALF     T_CARR-2          T           Carrington Power Ltd
# 6592      BOALF    T_CGTHW-1          T    Corriegarth Wind Energy LTD
# 6593      BOALF    T_CGTHW-1          T    Corriegarth Wind Energy LTD
# 6594      BOALF    T_CLDSW-1          T  Clyde Windfarm (Scotland) Ltd
# 6595      BOALF    T_CLDSW-1          T  Clyde Windfarm (Scotland) Ltd
# 6596      BOALF     T_DAMC-1          T              VPI Power Limited
# 6597      BOALF     T_DAMC-1          T              VPI Power Limited
# 6598      BOALF     T_EECL-1          T              Uniper UK Limited
# 6599      BOALF     T_EECL-1          T              Uniper UK Limited
# 6600      BOALF     T_EECL-1          T              Uniper UK Limited
# 6601      BOALF     T_EECL-1          T              Uniper UK Limited
# 6602      BOALF     T_KEAD-2          T      Keadby Generation Limited
# 6603      BOALF     T_KEAD-2          T      Keadby Generation Limited
# 6604      BOALF     T_KEAD-2          T      Keadby Generation Limited
# 6605      BOALF    T_KPMRW-1          T        Banks Renewable Limited
# 6606      BOALF    T_KPMRW-1          T        Banks Renewable Limited
# 6607      BOALF     T_LBAR-1          T          RWE Generation UK plc
# 6608      BOALF     T_LBAR-1          T          RWE Generation UK plc
# 6609      BOALF     T_LBAR-1          T          RWE Generation UK plc
# 6610      BOALF     T_LBAR-1          T          RWE Generation UK plc
# 6611      BOALF    T_PEMB-11          T          RWE Generation UK plc
# 6612      BOALF    T_PEMB-41          T          RWE Generation UK plc
# 6613      BOALF    T_PEMB-41          T          RWE Generation UK plc
# 6614      BOALF    T_PEMB-41          T          RWE Generation UK plc
# 6615      BOALF    T_PEMB-41          T          RWE Generation UK plc
# 6616      BOALF     T_RATS-3          T              Uniper UK Limited
# 6617      BOALF     T_RATS-3          T              Uniper UK Limited
# 6618      BOALF     T_RATS-3          T              Uniper UK Limited
# 6619      BOALF     T_SEAB-2          T          Seabank Power Limited
# 6620      BOALF     T_SEAB-2          T          Seabank Power Limited
# 6621      BOALF     T_SEAB-2          T          Seabank Power Limited
# 6622      BOALF     T_SPLN-1          T    Spalding Energy Company Ltd
# 6623      BOALF     T_SPLN-1          T    Spalding Energy Company Ltd
# 6624      BOALF    T_STRNW-1          T      Strathy Wind Farm Limited
# 6625      BOALF    T_WDRGW-1          T    Windy Rig Wind Farm Limited
# 6626      BOALF    T_WDRGW-1          T    Windy Rig Wind Farm Limited
# 6627      BOALF    T_WISTW-2          T     BROCKLOCH RIG WINDFARM LTD
# 6628      BOALF    T_WISTW-2          T     BROCKLOCH RIG WINDFARM LTD
#
#      ngcBMUnitName settlementDate  settlementPeriod            timeFrom  \
# 6580       LCSMH-1     2023-07-03                 9 2023-07-03 02:09:00
# 6581       LCSMH-1     2023-07-03                 9 2023-07-03 03:19:00
# 6582       ASHWW-1     2023-07-03                 9 2023-07-03 02:46:00
# 6583       BRYBW-1     2023-07-03                 9 2023-07-03 02:45:00
# 6584        SHOS-1     2023-07-03                 9 2023-07-03 02:42:00
# 6585        SHOS-1     2023-07-03                 9 2023-07-03 03:12:00
# 6586        SHOS-1     2023-07-03                 9 2023-07-03 03:20:00
# 6587        SHOS-1     2023-07-03                 9 2023-07-03 03:23:00
# 6588        CARR-2     2023-07-03                 9 2023-07-03 02:49:00
# 6589        CARR-2     2023-07-03                 9 2023-07-03 03:19:00
# 6590        CARR-2     2023-07-03                 9 2023-07-03 03:21:00
# 6591        CARR-2     2023-07-03                 9 2023-07-03 03:23:00
# 6592       CGTHW-1     2023-07-03                 9 2023-07-03 02:24:00
# 6593       CGTHW-1     2023-07-03                 9 2023-07-03 03:04:00
# 6611       T                 F                  F               F
# 6612       T                 F                  F               F
# 6613       T                 F                  F               F
# 6614       T                 F                  F               F
# 6615       T                 F                  F               F
# 6616       T                 F                  F               F
# 6617       T                 F                  F               F
# 6618       T                 F                  F               F
# 6619       T                 F                  F               F
# 6620       T                 F                  F               F
# 6621       T                 F                  F               F
# 6622       T                 F                  F               F
# 6623       T                 F                  F               F
# 6624       T                 F                  F               F
# 6625       T                 F                  F               F
# 6626       T                 F                  F               F
# 6627       T                 F                  F               F
# 6628       T                 F                  F               F
#
#       bidOfferLevelFrom bidOfferLevelTo
# 6580              -42.0           -42.0
# 6581              -42.0            -1.0
# 6582                5.0            14.0
# 6583               15.0            24.0
# 6584              220.0           220.0
# 6585              220.0           140.0
# 6586              140.0            60.0
# 6587               60.0             0.0
# 6588              176.0           176.0
# 6589              176.0           130.0
# 6590              130.0           100.0
# 6591              100.0             0.0
# 6592                3.0             3.0
# 6593                3.0            47.0
# 6594                0.0             0.0
# 6595                0.0            59.0
# 6596              480.0           260.0
# 6597              260.0             0.0
# 6598              240.0           240.0
# 6599              240.0           125.0
# 6600              125.0            70.0
# 6601               70.0             0.0
# 6602              380.0           380.0
# 6603              380.0            10.0
# 6604               10.0             0.0
# 6605                0.0             0.0
# 6606                0.0            40.0
# 6607              375.0           375.0
# 6608              375.0           160.0
# 6609              160.0           140.0
# 6610              140.0             0.0
# 6611              219.0           219.0
# 6612              219.0           219.0
# 6613              219.0           150.0
# 6614              150.0            80.0
# 6615               80.0             0.0
# 6616              230.0           230.0
# 6617              230.0           140.0
# 6618              140.0             0.0
# 6619              240.0           240.0
# 6620              240.0           150.0
# 6621              150.0             0.0
# 6622              335.0           335.0
# 6623              335.0             0.0
# 6624                0.0             0.0
# 6625                0.0             0.0
# 6626                0.0            43.0
# 6627                0.0             0.0
# 6628                0.0            51.0
#
# [49 rows x 27 columns]

# %% [markdown]
# ##### 5.2.47	Historic Acceptances

# %%
'''
'HISTACCEPTS': [ ('SettlementDate', date, ['optional']),
                 ('SettlementPeriod', str, ['optional']) ]
'''

# %%
generation = api.request('HISTACCEPTS', SettlementDate='2020-01-01')

# %%
pd.DataFrame(generation)
# Out:
#    recordType    bmuName  bidOfferAcceptanceNumber    acceptanceTime  \
# 0         HAD  T_EDINW-1                     39802  2020-01-01 02:06
# 1         HAD   T_SHBA-1                    156312  2020-01-01 02:07
# 2         HAD   T_SCCL-1                     79810  2020-01-01 02:23
# 3         HAD   T_SHBA-2                    141797  2020-01-01 02:24
# 4         HAD   T_SCCL-2                     78322  2020-01-01 02:24
# 5         HAD   T_EECL-1                    115315  2020-01-01 02:30
# 6         HAD   T_COSO-1                    165730  2020-01-01 02:31
# 7         HAD   T_GRAI-7                     74554  2020-01-01 02:31
# 8         HAD   T_GRAI-6                     69926  2020-01-01 02:31
# 9         HAD   T_STAY-4                     76511  2020-01-01 02:31
# 10        HAD  T_PEMB-11                     72884  2020-01-01 02:32
# 11        HAD   T_SPLN-1                    168276  2020-01-01 02:35
# 12        HAD   T_SPLN-1                    168277  2020-01-01 02:38
# 13        HAD   T_SCCL-2                     78323  2020-01-01 02:38
# 14        HAD   T_SHBA-1                    156313  2020-01-01 02:38
# 15        HAD  T_EDINW-1                     39803  2020-01-01 02:48
# 16        HAD   T_SPLN-1                    168278  2020-01-01 02:52
# 17        HAD   T_MRWD-1                     99728  2020-01-01 02:53
# 18        HAD   T_EECL-1                    115316  2020-01-01 02:54
# 19        HAD  T_PEMB-11                     72885  2020-01-01 02:57
# 20        HAD   T_COSO-1                    165731  2020-01-01 02:57
# 21        HAD   T_EECL-1                    115317  2020-01-01 02:58
# 22        HAD   T_SCCL-1                     79811  2020-01-01 02:59
# 23        HAD   T_PEHE-1                    122485  2020-01-01 02:59
# 24        HAD   T_MRWD-1                     99729  2020-01-01 03:00
# 25        HAD   T_SPLN-1                    168279  2020-01-01 03:00
# 26        HAD   T_SHBA-2                    141798  2020-01-01 03:01
# 27        HAD   T_MRWD-1                     99730  2020-01-01 03:05
# 28        HAD   T_EECL-1                    115318  2020-01-01 03:06
# 29        HAD   T_COSO-1                    165732  2020-01-01 03:06
# 30        HAD  T_PEMB-11                     72886  2020-01-01 03:07
# 31        HAD   T_SPLN-1                    168280  2020-01-01 03:10
# 32        HAD   T_SCCL-2                     78324  2020-01-01 03:10
# 33        HAD   T_SHBA-1                    156314  2020-01-01 03:10
# 34        HAD   T_SHBA-2                    141799  2020-01-01 03:10
# 35        HAD   T_SPLN-1                    168281  2020-01-01 03:12
# 36        HAD   T_EECL-1                    115319  2020-01-01 03:14
# 37        HAD   T_MRWD-1                     99731  2020-01-01 03:15
# 38        HAD   T_SPLN-1                    168283  2020-01-01 03:23
# 39        HAD   T_PEHE-1                    122486  2020-01-01 03:25
#
#     offerPrice  bidPrice  activeFlag
# 0          0.0     -85.0        True
# 1          2.0       0.0        True
# 2         30.0       5.2        True
# 3          2.0       0.0        True
# 4         30.0       5.1        True
# 5         50.9      20.0        True
# 6         52.0      45.0        True
# 7         75.0      30.0        True
# 8         74.5      14.0        True
# 9         83.0      30.0        True
# 10        50.0      45.0        True
# 11        50.5      40.0        True
# 12        50.5      40.0        True
# 13        30.0       5.1        True
# 14         2.0       0.0        True
# 15         0.0     -85.0        True
# 16        50.5      40.0        True
# 17        51.5      30.0        True
# 18        50.9      20.0        True
# 19        50.0      45.0        True
# 20        52.0      45.0        True
# 21        50.9      20.0        True
# 22        30.0       5.2        True
# 23        50.0      30.0        True
# 24        51.5      30.0        True
# 25        50.5      40.0        True
# 26         2.0       0.0        True
# 27        51.5      30.0        True
# 28        50.9      20.0        True
# 29        52.0      45.0        True
# 30        50.0      45.0        True
# 31        50.5      40.0        True
# 32        30.0       5.1        True
# 33         2.0       0.0        True
# 34         2.0       0.0        True
# 35        50.5      40.0        True
# 36        50.9      20.0        True
# 37        51.5      30.0        True
# 38        50.5      40.0        True
# 39        50.0      30.0        True

# %% [markdown]
# ##### XXX
